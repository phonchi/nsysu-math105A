# %% [markdown]
# # Assignment 7

# %% [markdown]
# #### Student ID: *Double click here to fill the Student ID*
#
# #### Name: *Double click here to fill the name*

# %% [markdown]
# ### 1. Which of the following is not a control statement (structure)?
#
# (A) If-else statement
#
# (B) While statement
#
# (C) For statement
#
# (D) Assignment statement

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (D)

# %% [markdown]
# ### 2. What is the output of the following program:
#
# ```
# x = 2022
# x = x + 1
# print(x)
# ```
# (A) 2022
#
# (B) 2023
#
# (C) x + 1
#
# (D) Error because x = x + 1 is not possible mathematically

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (B)

# %% [markdown]
# ### 3. Assume that we execute the following assignment statements:
#
# ```
# w = 17
# h = 12.0
# a1 = (w // 2)
# a2 = (w / 2.0)
# a3 = (h / 3)
# a4 = (1.0 + (2 * 5))
# ```
# which variable has different data type compared with the others?
#
# (A) a1
#
# (B) a2
#
# (C) a3
#
# (D) a4

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (A)

# %% [markdown]
# ### 4. What does the following code snippet do?
#
# ```
# s = 0
# for i in range(3,10):
#   s+=i
# ```
#
# (A) Calculate the sum 4+5+6+7+...+9
#
# (B) Calculate the sum 3+4+5+6+...+10
#
# (C) Calculate the sum 3+4+5+6+...+9
#
# (D) Calculate the sum 4+5+6+7+...+10

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (C)

# %% [markdown]
# ### 5. What is the output of the following program?
#
# ```
# lst = ['a', 'b', 'c', 'd', 'e']
# print(lst[1:])
# ```
#
# (A) []
#
# (B) ['b']
#
# (C) ['b', 'c', 'd', 'e']
#
# (D) None of the above

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (C)

# %% [markdown]
# ### 6.  Suppose the Python function `Big_Print` is
# defined by
#
# ```
# def Big_Print (Y):
#   Y[3] = 7
#   print(Y)
#
# X = [1,3,5,9]
# Big_Print(X)
# print(X)
# ```
#
# What will be printed when the above code is executed and why?

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# [1,3,5,7]
#
# [1,3,5,7]
#
# Because the list is mutable and when it pass to the function is pass by reference.

# %% [markdown]
# ### 7. What is the difference between the compilation and interpretation?

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# Compilation  will first preprocess or translate  the  whole  source  program  into  the  object  module before executing the program. Interpretation, on the other hand, will process and translating each line of the source program into the corresponding line of the object program and executing the translated line.

# %% [markdown]
# ### 8. What is the difference between tuple and list in Python and when will you use tuple instead of list?

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# Lists are more common than tuples, mostly because they are mutable while tuples are immutable. But there are a few cases where you might prefer tuples:
#
# 1. In some contexts, like a return statement, it is syntactically simpler to create a tuple than a list. In other contexts, you might prefer a list.
#
# 2. If you want to use a sequence as a dictionary key, you have to use an immutable type like a tuple or string.
#
# 3. If you are passing a sequence as an argument to a function, using tuples reduces the potential for unexpected behavior due to aliasing.

# %% [markdown]
# ### 9. The following code calculate 1+2...+100 using loops and print the intermediate results every 10 iterations. Try to change the loop using for statement.

# %%
sum = 0
i = 1
while i <= 100:
  sum +=i
  if i %10 == 0:
    print(sum)
  i = i+1
# Out:
# 55
# 210
# 465
# 820
# 1275
# 1830
# 2485
# 3240
# 4095
# 5050

# %%
sum = 0
for i in range(1,101):
  sum +=i
  if i %10 == 0:
    print(sum)
# Out:
# 55
# 210
# 465
# 820
# 1275
# 1830
# 2485
# 3240
# 4095
# 5050

# %% [markdown]
# ### (10) Write a simple program that asks the user to enter a list of numbers.  At the end when the user enters “end” the program should prints out the maximum and minimum of the numbers. You can assume that the user always input an integer.

# %%
# Your code here
# Sample output is below
lst = []
while True :
  n = input('Please input number: ')
  if n == ('end') :
    break
  lst.append(int(n))
print('Maximum: ',max(lst))
print('Minimum: ',min(lst))
# Out:
# Please input number: 3
# Please input number: -1
# Please input number: 5
# Please input number: 7
# Please input number: 12
# Please input number: end
# Maximum:  12
# Minimum:  -1
