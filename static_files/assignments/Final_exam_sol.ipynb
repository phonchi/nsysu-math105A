# %% [markdown]
# # Introduction to Computer Science, Final Exam

# %% [markdown]
# #### Student ID: *Double click here to fill the Student ID*
#
# #### Name: *Double click here to fill the name*

# %% [markdown]
# ## A.	Single Choice Questions (3%, 45%)

# %% [markdown]
# (1) Consider an application scenario in which you will retrieve data items in the reversed order they were put into the container. Which data structure will be best suited for the container in this case?
#
# (A) Queue
#
# (B) Graph
#
# (C) Binary search tree
#
# (D) Stack

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (D)

# %% [markdown]
# ### (2) Which of the following statement will produce different results than the other three in Python? (Hint: You can execute the code and compare its output)
#
# (A) `list("final")`
#
# (B) `list({'f', 'i', 'n', 'a', 'l'})`
#
# (C) `list(['f', 'i', 'n', 'a', 'l'])`
#
# (D) `list(('f', 'i', 'n', 'a', 'l'))`

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (B)

# %% [markdown]
# ### (3)  Which of the following is a task that is not performed by the kernel of a typical operating system?
#
# (A) Receives and interprets the commands entered by the user
#
# (B) Scheduling the access to the computer's input/output devices
#
# (C) Avoid the deadlock and starvation of the process
#
# (D) Coordinating the machine's use of main memory

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (A) - This is part of shell

# %% [markdown]
# ### (4) Which of the following statement is NOT true?
#
# (A) The only language understood by a computer is machine language. However, writing programs in this language is machine-dependent and very tedious.
#
# (B) High-level languages are portable to many different computers, allowing the programmer to concentrate on the application rather than the intricacies of the computer’s organization.
#
# (C) In Python, if you pass a sequence as an argument to a function, using a list can reduce the potential for unexpected behavior due to aliasing.
#
# (D) In Python, both string and tuple are immutable data types, meaning that they cannot be modified.

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (C) - Should use tuple

# %% [markdown]
# ### (5) What is the total number of nodes you will visit when you search number 30 in the following binary search tree?
#
# ```
#    17
#   /  \
#   6  19
#  / \ / \
#  3 9 18 22
# ```
#
# (A) 2
#
# (B) 3
#
# (C) 4
#
# (D) 5

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (B)

# %% [markdown]
# ### (6) Consider the list `[1,5,9,15,21,25,29]` which statement is NOT true?
#
# (A) 9 will be found more quickly than 15 if we use a binary search algorithm to find these two entries in the list.
#
# (B) 15 will be found more quickly than 25 if we use a sequential search algorithm to find these two entries in the list.
#
# (C) 15 will be found more quickly if we use a binary search algorithm rather than a sequential search algorithm.
#
# (D) 1 will be found more quickly if we use a sequential search algorithm rather than a binary search algorithm.

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (A)

# %% [markdown]
# ### (7) Which of the following statement is NOT true?
#
# (A) Queue is a first in, first out (FIFO) structure.
#
# (B) A stack can be implemented using either an array or a linked list
#
# (C) In a directed graph, each edge, which connects two vertices, has a direction from one vertex to the other.
#
# (D) A binary search tree (BST) is a binary tree with one extra property: the key value of each node is smaller than the key values of all nodes in each left subtree and greater than the value of all nodes in each right subtree

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (D)

# %% [markdown]
# ### (8) Which of the following statement is true?
#
#
# (A) A job in the hold state can go to either the ready, terminated, or waiting states.
#
# (B) A program becomes a process immediately when the operating system selects it.
#
# (C) To prevent starvation, an operating system will try to put more resource restrictions on processes.
#
# (D) The file manager is responsible for archiving and backup.

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (D)

# %% [markdown]
# ### (9) Which of the following lists would NOT be obtained at some point when applying the bubble sort algorithm (the element is swap from left to right. The largest element in the unsorted list will be swapped towards the last index after every pass) to the list below? (Hint: You can use https://visualgo.net/en/sorting to simulate the process)
#
# ```python
# [4,2,3,5,7,9,1]
# ```
#
# (A) `[2,3,4,5,7,1,9]`
#
# (B) `[1,2,3,4,5,7,9]`
#
# (C) `[2,3,1,4,5,7,9]`
#
# (D) `[2,1,3,5,7,9,4]`

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (D)

# %% [markdown]
# ### (10) Which of the following statement is NOT true?
#
# (A) For a list of `n` elements, the selection sort needs `n` pass to completely rearrange the data.
#
# (B) There are mainly two approaches to writing algorithms for solving a repetition problem. One uses iteration, and the other uses recursion.
#
# (C) Computer scientists have defined three constructs for a structured program which include sequence, decision, and repetition.
#
# (D) An algorithm is an ordered set of unambiguous steps that produce a result and terminates in a finite time.

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (A)

# %% [markdown]
# ### (11) When you try to calculate the location of an entry in a two-dimensional array in main memory, which of the following is not used in the calculation? Assuming that it stores the array in column-major order.
#
# (A) Number of rows in the array.
#
# (B) The starting address of the first element.
#
# (C) The row number of the element.
#
# (D) Number of columns in the array.

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (D)

# %% [markdown]
# ### (12) Which of the following statement will produce different results than the other three in Python, assuming that `s="nsysumath"` (Hint: You can execute the code and compare its output)
#
#
# (A) `s[-2:]`
#
# (B) `s[7:]`
#
# (C) `s[7:len(s)]`
#
# (D) `s[-2,-1]`

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (D)

# %% [markdown]
# ### (13) Which of the following statement is true?
#
# (A) Insertion and deletion in an array are much easier than in a linked list.
#
# (B) The search algorithm for an array can only be sequential because the element in an array has no specific names that allow random access.
#
# (C) An array can be considered a special case of an array of records in which each element is a record with only a single field.
#
# (D) When applying the sequential search algorithm to a sorted linked list, the `cur` pointer will always point to the null if the target is not found.

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (C)

# %% [markdown]
# ### (14) Which of the following tree is NOT a binary search tree?
#
# (A)
# ```
#    15
#   /  \
#   6  19
#  / \
#  3 8
# ```
#
# (B)
# ```
#    13
#   /  \
#   6  19
#  / \
#  3 5
# ```
#
# (C)
# ```
#    13
#   /
#   8
#  /
#  1
# ```
#
# (D)
# ```
#    21
#   /  \
#   8  23
#  /
#  1
# ```

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (B)

# %% [markdown]
# ### (15) Which of the following statement is NOT true?
#
#
# (A) In the demand paging scheme, the program can be swapped between memory and disk one or more times.
#
# (B) In the partitioning scheme, the memory manager has the option to compact the partitions to remove the holes and create new partitions.
#
# (C) In the paging scheme, the pages need not be in memory at the same time for execution.
#
# (D) In the demand segmentation scheme, the program can be divided into differently sized sections.

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (C) - Should be demand paging or demand segmentation

# %% [markdown]
# ## B.	Short-answer and coding questions

# %% [markdown]
# ### (16) Consider a variant of the Fibonacci sequence, which is defined as follows: (6%)
#
# $$\begin{cases}
#   \displaystyle F(0)=1, F(1)=4  \\
#   \displaystyle F(n) = F(n-1) + F(n-2) \quad \text{n > 1} \\
#   \end{cases}$$
#
# The following program segment is designed to calculate the nth term of the above modified Fibonacci sequence:

# %%
def fib_r(n):
  if n == 0:
    return 1
  elif n == 1:
    return 4
  else:
    return fib_r(n-1) + fib_r(n-2)

# %% [markdown]
# Modify the above program to calculate the sequence using loop by completing the following function. Note your code should pass the following test data.

# %%
def fib_i(n):
  """
    Parameters
    ----------
    n: int
        The index of the target number in the sequence
    Returns
    -------
    result : int
        the nth term of the number in the sequence 
  """
  n0 = 1
  n1 = 4
  if n == 0:
    return 1
  elif n == 1:
    return 4
  for i in range(n-1):
    result = n1 + n0
    n1, n0 = result, n1
  return result

# %%
# Test data

assert(fib_r(0)==fib_i(0))
assert(fib_r(1)==fib_i(1))
assert(fib_r(6)==fib_i(6))
assert(fib_r(10)==fib_i(10))

# %% [markdown]
# ### (17)  What is the main difference between queue and stack? Give one example that you would use stack to handle your problem. (5%)

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# A stack is a restricted linear list in which all additions and deletions are made at one end, the top. The stacks are known as a last in, first out (LIFO) data structure.
#
# A queue, on the other hand, is a linear list in which data can only be inserted at one end, called the rear, and deleted from the other end, called the front. A queue is a first in, first out (FIFO)  structure.
#
# Stack can be used when we want to pairing the data For instance, when we type an expression with a lot of parentheses, we often forget to pair the parentheses. The compiler can then uses a stack to check that all opening parentheses are paired with a closing parentheses.

# %% [markdown]
# ### (18) The linked list in our slide is defined as follows: (6%)

# %%
class LinkedList:
  def __init__(self, nodes=None):
    self.head = None
    if nodes:
      node = Node(data=nodes.pop(0)) #pop will pop out the first entry of the list
      self.head = node
      for elem in nodes:
        node.link = Node(data=elem)
        node = node.link
  def __repr__(self): #This is to beautify printing, don't worry about this
    node = self.head
    nodes = []
    while node is not None:
      nodes.append(str(node.data))
      node = node.link
    nodes.append("None")
    return " -> ".join(nodes)

class Node:
  def __init__(self, data):
    self.data = data
    self.link = None
  def __repr__(self):
    return str(self.data)

# %% [markdown]
# Complete the following function to calculate the summation of two liked lists with the same length elementwise and store the results into a list. Note your code should pass the following test data.

# %%
def SumLinkedList(ilist1, ilist2):
  """
    Parameters
    ----------
    ilist1: linked list
        The first input linked list that contains positive numbers.
    ilist2: linked list
        The second input linked list that contains positive numbers.
    Returns
    -------
    olist : list
        The output list that contains the summation of the two input linked list, note that summation is performed elementwise
  """
  # Your code here
  olist = []
  walker1 = ilist1.head
  walker2 = ilist2.head
  while walker1 != None:
    olist.append(walker1.data + walker2.data)
    walker1 = walker1.link
    walker2 = walker2.link  
  return olist

# %%
# Test data
import numpy as np

ilist1 = LinkedList([3,5,7,9])
ilist2 = LinkedList([2,4,6,8])
ilist3 = LinkedList([3,11,12,15,19])
ilist4 = LinkedList([1,2,24,36,48])
assert(SumLinkedList(ilist1, ilist2)) == list(np.array([3,5,7,9])+np.array([2,4,6,8]))
assert(SumLinkedList(ilist3, ilist4)) == list(np.array([3,11,12,15,19])+np.array([1,2,24,36,48]))

# %% [markdown]
# ### (19) Modify the bubble sort program in our slides to sort the following list of scores. (8%)
#
# ```python
# grades = [
#         { 'name': 'david', 'score': 80, 'id':0},
#         { 'name': 'allen', 'score': 90, 'id':1},
#         { 'name': 'bob',  'score': 100, 'id':2},
#         { 'name': 'cathy', 'score': 90, 'id':3},
#         { 'name': 'cathy', 'score': 85, 'id':4}
#       ]
# ```
#
# Your `bubble_sort` function should be able to handle a list of keys. For instance, if the user want to sort grades base on Key 1 then Key 2, the list should be `['1', '2']`. For example,
#
# ```python
# bubble_sort(grades, key=['score', 'name'])
# ```
#
# should output
#
# ```python
#   [
#     {'name': 'allen', 'score': 90, 'id': 1},
#     {'name': 'bob', 'score': 100, 'id': 2},
#     {'name': 'cathy', 'score': 85, 'id': 4},
#     {'name': 'cathy', 'score': 90, 'id': 3},
#     {'name': 'david', 'score': 80, 'id': 0}
#   ]
# ```
#
# while
#
# ```python
# bubble_sort(grades, key=['score', 'name'])
# ```
#
# should output
#
# ```python
#   [
#     {'name': 'david', 'score': 80, 'id': 0},
#     {'name': 'cathy', 'score': 85, 'id': 4},
#     {'name': 'allen', 'score': 90, 'id': 1},
#     {'name': 'cathy', 'score': 90, 'id': 3},
#     {'name': 'bob', 'score': 100, 'id': 2}
#   ]
# ```
#
# Notice that you should complete the following function and produce the above results.
#
# Hint: The string can be sorted as an integer using `<` or `>` operator since Python will compare their ASCII code! You can access the score/name using `grades[idx][score]` or `grades[idx][name]`. In addition, **you can try to first sort the list according to key 1 then sort the resulting list according to key 2**.

# %%
def bubble_sort(arr, keys):
  """
    Parameters
    ----------
    arr: list of dictionaries
        The unsorted input list of dictionaries
    keys: list of str
        Sort the data according to the key
    Returns
    -------
    arr : list of dictionaries
        The sorted list of dictionaries
  """
  n = len(arr)
  ## Move the wall one element to the right
  for key in keys[-1::-1]:
    for wall in range(n-1):
      ## bubble each element up to the right
      for j in range(n-1, wall, -1):
        if arr[j][key] < arr[j-1][key]:
          arr[j], arr[j-1] = arr[j-1], arr[j]
  return arr

# %%
grades = [
        { 'name': 'david', 'score': 80, 'id':0},
        { 'name': 'allen', 'score': 90, 'id':1},
        { 'name': 'bob',  'score': 100, 'id':2},
        { 'name': 'cathy', 'score': 90, 'id':3},
        { 'name': 'cathy', 'score': 85, 'id':4}
      ]

# %%
bubble_sort(grades, keys=['name', 'score'])
# Out:
# [{'name': 'allen', 'score': 90, 'id': 1},
#  {'name': 'bob', 'score': 100, 'id': 2},
#  {'name': 'cathy', 'score': 85, 'id': 4},
#  {'name': 'cathy', 'score': 90, 'id': 3},
#  {'name': 'david', 'score': 80, 'id': 0}]

# %%
bubble_sort(grades, keys=['score', 'name'])
# Out:
# [{'name': 'david', 'score': 80, 'id': 0},
#  {'name': 'cathy', 'score': 85, 'id': 4},
#  {'name': 'allen', 'score': 90, 'id': 1},
#  {'name': 'cathy', 'score': 90, 'id': 3},
#  {'name': 'bob', 'score': 100, 'id': 2}]

# %% [markdown]
# ### (20) The following code calculate 1$\times$3$\times$5$\times$...$\times$23 using loops and print the intermediate results every 3 iterations. Try to change the loop using `for` statement. (6%)
#
# Hint: You can specify the step in the range function `range(start, stop, step=1)` and you may find `enumerate` useful in this problem.

# %%
prod = 1
i = 1
counter = 1
while i <= 23:
  prod = prod*i
  if counter %3 == 0:
    print(prod)
  counter = counter+1
  i = i+2
# Out:
# 15
# 10395
# 34459425
# 316234143225

# %%
prod = 1
for counter, i in enumerate(range(1,24,2)):
  prod = prod*i
  if (counter+1) %3 == 0:
    print(prod)
# Out:
# 15
# 10395
# 34459425
# 316234143225

# %% [markdown]
# ### (21) An operating system uses virtual memory but requires the whole program to be in physical memory during execution (no paging or segmentation). The size of physical memory is 500 MB. The size of virtual memory is 2 GB. How many programs of size 20 MB can be run concurrently by this operating system? Among the above running program, how many of them can be in memory at any time? How many of them must be on disk? (6%)

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# (a) Number of program should be (2000+500)/20=125.
#
# (b) 25 can be in memory and the remaining 100 should be on the disk.

# %% [markdown]
# ### (22) A binary tree hase seven nodes. The following shows the preorder and postorder traversal of the tree. Can you draw the tree? If yes, please draw the tree. If the tree does not exist, please explain why not. (4%)
#
# ```
# Preorder: ABDEHFG
# Postorder: BHEDFAG
# ```

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# No, because they have different root, the root of the preorder traversal is at the begining which is A. While the root of postorder traversal is at the end which is G.

# %% [markdown]
# ### (23) We have stored the two-dimensional array students in the memory. The array is 10 × 50 (10 rows and 50 columns). Show the address of the element `students[2][3]` assuming that the element `student[0][0]` is stored in the memory location with address 20 and each element occupies only one memory location. The computer uses row-major storage. (4%)

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# We  can  use  the  following  formula  to  find  the  location  of  an  element,  assuming  each  element occupies one memory location:
#
# $y = x + Cols \times i + j$
#
# where `x` defines the start address, Cols defines the number of columns in the array, `i` defines the row number of the element, `j` defines the column number of the element, and `y` is
# address we are looking for. In our example, `x` is 20, `Cols` is 50, `i` is 2 and `j` is 3. We are looking for the value of `y`:
#
# $y = 20 + 50 \times 2 + 3 = 123$

# %% [markdown]
# ### (24) Assuming that we have a queue Q that implements the four operations defined in stack ADT. What will be the content of the queue after the following operation and why? Be sure to point out the front and rear of the queue in your answer. (4%)
#
# ```
# Q = queue()
# enqueue(Q,5)
# enqueue(Q,20)
# dequeue(Q)
# if (noy empty(Q)) dequeue(Q)
# enqueue(Q,2)
# enqueue(Q,5)
# ```

# %% [markdown]
# > Ans: *double click here to answer the question.*
#
# After the first step: [5]
#
# After the second step: [5,20]
#
# After the third step: [20]
#
# After the fourth step: []
#
# After the fifth step: [2]
#
# After the sixth step: [2,5]
#
# The content will be [2,5] where 2 is in the front and 5 is in the rear.

# %% [markdown]
# ### (25) The binary search tree in our slide is defined as follows: (6%)

# %%
class tree:
  def __init__(self):
    self.data = 0
    self.left = None
    self.right = None
  def __repr__(self):
    lines, *_ = self._display_aux()
    return "\n".join(lines)
  def _display_aux(self):
    # https://stackoverflow.com/questions/34012886/print-binary-tree-level-by-level-in-python
    """Returns list of strings, width, height, and horizontal coordinate of the root."""
    # No child.
    if self.right is None and self.left is None:
      line = '%s' % self.data
      width = len(line)
      height = 1
      middle = width // 2
      return [line], width, height, middle

    # Only left child.
    if self.right is None:
      lines, n, p, x = self.left._display_aux()
      s = '%s' % self.data
      u = len(s)
      first_line = (x + 1) * ' ' + (n - x - 1) * '_' + s
      second_line = x * ' ' + '/' + (n - x - 1 + u) * ' '
      shifted_lines = [line + u * ' ' for line in lines]
      return [first_line, second_line] + shifted_lines, n + u, p + 2, n + u // 2

    # Only right child.
    if self.left is None:
      lines, n, p, x = self.right._display_aux()
      s = '%s' % self.data
      u = len(s)
      first_line = s + x * '_' + (n - x) * ' '
      second_line = (u + x) * ' ' + '\\' + (n - x - 1) * ' '
      shifted_lines = [u * ' ' + line for line in lines]
      return [first_line, second_line] + shifted_lines, n + u, p + 2, u // 2

    # Two children.
    left, n, p, x = self.left._display_aux()
    right, m, q, y = self.right._display_aux()
    s = '%s' % self.data
    u = len(s)
    first_line = (x + 1) * ' ' + (n - x - 1) * '_' + s + y * '_' + (m - y) * ' '
    second_line = x * ' ' + '/' + (n - x - 1 + u + y) * ' ' + '\\' + (m - y - 1) * ' '
    if p < q:
      left += [n * ' '] * (q - p)
    elif q < p:
      right += [m * ' '] * (p - q)
    zipped_lines = zip(left, right)
    lines = [first_line, second_line] + [a + u * ' ' + b for a, b in zipped_lines]
    return lines, n + m + u, max(p, q) + 2, n + u // 2    

def create_tree(root,val):  # create a binary tree
  newnode = tree()
  newnode.data = val
  newnode.left = None
  newnode.right = None
  if root == None:
    root = newnode
    return root
  else:
    current = root
    while current != None:
      backup = current
      if current.data > val:
        current = current.left
      else:
        current = current.right
    if backup.data > val:
      backup.left = newnode
    else:
      backup.right = newnode
  return root

data=[17,6,3,14,19,5,11,22,18,30]
ptr = None
root = None
for i in range(len(data)):
  ptr=create_tree(ptr,data[i])

ptr
# Out:
#    ____17___
#   /         \
#  _6___     19_
# /     \   /   \
# 3    14  18  22_
#  \  /           \
#  5 11          30

# %% [markdown]
# Complete the following function so that it will return the nodes it has been visited when it match the target or the algorithm stops. Note that the nodes should be store into a list and your code should pass the following test data.

# %%
def search(ptr,target):  
  """
    Parameters
    ----------
    ptr: tree
        The input binary search tree
    target: int 
        The target value.
    Returns
    -------
    L: list
        The nodes that has been visited
  """   
  L = []
  while True:
    if ptr == None:
      return L
    if ptr.data == target:
      L.append(ptr.data)
      return L
    elif ptr.data > target:
      L.append(ptr.data)
      ptr = ptr.left
    else:
      L.append(ptr.data)
      ptr = ptr.right

# %%
# Test data
assert set(search(ptr,11)) == set([17, 6, 14, 11])
assert set(search(ptr,22)) == set([17, 19, 22])
assert set(search(ptr,50)) == set([17, 19, 22, 30])
